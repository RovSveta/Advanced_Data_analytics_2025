# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import pandas as pd

#load dataset
mushroom_df = pd.read_csv("mushroom_encoded.csv")

# Define features and target
X = mushroom_df.drop("class", axis=1)
y = mushroom_df["class"]

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA
pca = PCA(n_components=10)
X_pca = pca.fit_transform(X_scaled)

# Explained variance
print("Explained variance ratio:", pca.explained_variance_ratio_)
print("Total explained variance:", sum(pca.explained_variance_ratio_))
# Out:
# Explained variance ratio: [0.05136819 0.04031711 0.03703886 0.03290563 0.02614278 0.02483457
#  0.02415062 0.02223604 0.02185459 0.02100281]
# Total explained variance: 0.30185119701747826
