# %% [markdown]
# ### Ydata-profiling for housing regression dataset
# #### I noticed that Ydata- profiling doesn't work with encoded variables, so I will use "ocean_proximity" variable with original categorical values.

# %%
import ydata_profiling
print(ydata_profiling.__version__)

# open the data as a pandas DataFrame
df = pd.read_csv("housing_for_ydata_report.csv")

# Generate the data profiling report, title is just for viewing purposes
report = ProfileReport(df, title='Housing data (regression), Advanced Data Analytics -course', explorative=True)

# create the report into a separate HTML -file
# you could send this HTML-file to your colleaque 
# and it should work!
report.to_file("ydata_housing_regression_report.html")
# Out:
# v4.17.0
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ![image.png](attachment:image.png)
