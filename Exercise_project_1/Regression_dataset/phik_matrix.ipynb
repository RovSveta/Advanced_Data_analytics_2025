# %% [markdown]
# ### Phik-matrix -> Associations

# %%
import phik
import pandas as pd

# load data
df = pd.read_csv("housing_modified.csv")

# compute phik-matrix values
phik_matrix = df.phik_matrix()

phik_matrix
# Out:
# interval columns not set, guessing: ['housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value', 'distance_to_nearest_city']
#                           housing_median_age  total_rooms  total_bedrooms  \
# housing_median_age                  1.000000     0.398169        0.361524
# total_rooms                         0.398169     1.000000        0.932763
# total_bedrooms                      0.361524     0.932763        1.000000
# population                          0.192669     0.838941        0.803485
# households                          0.349040     0.933930        0.987129
# median_income                       0.226603     0.195623        0.087083
# median_house_value                  0.215471     0.144070        0.118090
# ocean_proximity                     0.425758     0.050895        0.040972
# distance_to_nearest_city            0.429209     0.128965        0.101233
#
#                           population  households  median_income  \
# housing_median_age          0.192669    0.349040       0.226603
# total_rooms                 0.838941    0.933930       0.195623
# total_bedrooms              0.803485    0.987129       0.087083
# population                  1.000000    0.871241       0.037651
# households                  0.871241    1.000000       0.087436
# median_income               0.037651    0.087436       1.000000
# median_house_value          0.052307    0.125095       0.732841
# ocean_proximity             0.021675    0.045929       0.291326
# distance_to_nearest_city    0.045762    0.107231       0.326441
#
#                           median_house_value  ocean_proximity  \
# housing_median_age                  0.215471         0.425758
# total_rooms                         0.144070         0.050895
# total_bedrooms                      0.118090         0.040972
# population                          0.052307         0.021675
# households                          0.125095         0.045929
# median_income                       0.732841         0.291326
# median_house_value                  1.000000         0.617035
# ocean_proximity                     0.617035         1.000000
# distance_to_nearest_city            0.555581         0.711223
#
#                           distance_to_nearest_city
# housing_median_age                        0.429209
# total_rooms                               0.128965
# total_bedrooms                            0.101233
# population                                0.045762
# households                                0.107231
# median_income                             0.326441
# median_house_value                        0.555581
# ocean_proximity                           0.711223
# distance_to_nearest_city                  1.000000
