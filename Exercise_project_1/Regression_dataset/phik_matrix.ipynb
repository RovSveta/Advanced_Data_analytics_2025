# %% [markdown]
# ### Phik-matrix -> Associations

# %%
import phik
import pandas as pd

# load data
df = pd.read_csv("housing_modified.csv")

# compute phik-matrix values
phik_matrix = df.phik_matrix()

phik_matrix
# Out:
# interval columns not set, guessing: ['housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value', 'distance_to_nearest_city', 'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND', 'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY']
#                            housing_median_age  total_rooms  total_bedrooms  \
# housing_median_age                   1.000000     0.398820        0.361524
# total_rooms                          0.398820     1.000000        0.932763
# total_bedrooms                       0.361524     0.932763        1.000000
# population                           0.194096     0.839588        0.803485
# households                           0.349690     0.934418        0.987129
# median_income                        0.225064     0.195298        0.087083
# median_house_value                   0.216283     0.143464        0.118090
# distance_to_nearest_city             0.429087     0.129531        0.101233
# ocean_proximity_<1H OCEAN            0.189343     0.022213        0.000000
# ocean_proximity_INLAND               0.312688     0.062721        0.045231
# ocean_proximity_ISLAND               0.031508     0.000000        0.000000
# ocean_proximity_NEAR BAY             0.418883     0.022916        0.000000
#
#                            population  households  median_income  \
# housing_median_age           0.194096    0.349690       0.225064
# total_rooms                  0.839588    0.934418       0.195298
# total_bedrooms               0.803485    0.987129       0.087083
# population                   1.000000    0.871059       0.038442
# households                   0.871059    1.000000       0.087302
# median_income                0.038442    0.087302       1.000000
# median_house_value           0.051821    0.123301       0.733331
# distance_to_nearest_city     0.046380    0.108039       0.326799
# ocean_proximity_<1H OCEAN    0.011495    0.023207       0.230906
# ocean_proximity_INLAND       0.014892    0.044525       0.319339
# ocean_proximity_ISLAND       0.000000    0.000000       0.000000
# ocean_proximity_NEAR BAY     0.023659    0.000000       0.076334
#
#                            median_house_value  distance_to_nearest_city  \
# housing_median_age                   0.216283                  0.429087
# total_rooms                          0.143464                  0.129531
# total_bedrooms                       0.118090                  0.101233
# population                           0.051821                  0.046380
# households                           0.123301                  0.108039
# median_income                        0.733331                  0.326799
# median_house_value                   1.000000                  0.555313
# distance_to_nearest_city             0.555313                  1.000000
# ocean_proximity_<1H OCEAN            0.503802                  0.579365
# ocean_proximity_INLAND               0.746399                  0.783007
# ocean_proximity_ISLAND               0.078236                  0.032871
# ocean_proximity_NEAR BAY             0.213174                  0.438425
#
#                            ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# housing_median_age                          0.189343                0.312688
# total_rooms                                 0.022213                0.062721
# total_bedrooms                              0.000000                0.045231
# population                                  0.011495                0.014892
# households                                  0.023207                0.044525
# median_income                               0.230906                0.319339
# median_house_value                          0.503802                0.746399
# distance_to_nearest_city                    0.579365                0.783007
# ocean_proximity_<1H OCEAN                   1.000000                0.816020
# ocean_proximity_INLAND                      0.816020                1.000000
# ocean_proximity_ISLAND                      0.012877                0.003391
# ocean_proximity_NEAR BAY                    0.474158                0.369722
#
#                            ocean_proximity_ISLAND  ocean_proximity_NEAR BAY
# housing_median_age                       0.031508                  0.418883
# total_rooms                              0.000000                  0.022916
# total_bedrooms                           0.000000                  0.000000
# population                               0.000000                  0.023659
# households                               0.000000                  0.000000
# median_income                            0.000000                  0.076334
# median_house_value                       0.078236                  0.213174
# distance_to_nearest_city                 0.032871                  0.438425
# ocean_proximity_<1H OCEAN                0.012877                  0.474158
# ocean_proximity_INLAND                   0.003391                  0.369722
# ocean_proximity_ISLAND                   1.000000                  0.000000
# ocean_proximity_NEAR BAY                 0.000000                  1.000000
